# %%
import os
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ICGC_SAMPLE_ID = 'SA320818' #Sample we are reading
df = pd.read_csv('E:/Sequencing/simple_somatic_mutation/samples/' + ICGC_SAMPLE_ID + '.tsv', \
                 sep = '\t', low_memory=False)

# %%
pd.set_option('display.max_columns', 5000)

# %%
df.head()
# Out:
#   icgc_sample_id chromosome  chromosome_start  chromosome_end  \
# 0       SA320818          3         147424632       147424632
# 1       SA320818          3         147424632       147424632
# 2       SA320818          5          75054899        75054899
# 3       SA320818         15          60419020        60419020
# 4       SA320818         17          71121414        71121414
#
#    chromosome_strand             mutation_type reference_genome_allele  \
# 0                  1       deletion of <=200bp                       T
# 1                  1       deletion of <=200bp                       T
# 2                  1  single base substitution                       C
# 3                  1  single base substitution                       C
# 4                  1      insertion of <=200bp                       -
#
#   mutated_from_allele mutated_to_allele  total_read_count  \
# 0                   T                 -              41.0
# 1                   T                 -              35.0
# 2                   C                 T              25.0
# 3                   C                 T              42.0
# 4                   -                 A              30.0
#
#    mutant_allele_read_count   consequence_type gene_affected  \
# 0                      13.0  intergenic_region           NaN
# 1                      12.0  intergenic_region           NaN
# 2                      18.0  intergenic_region           NaN
# 3                       8.0  intergenic_region           NaN
# 4                      12.0  intergenic_region           NaN
#
#   transcript_affected
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
#5,9-12,14-17,20-21,26,29-30
